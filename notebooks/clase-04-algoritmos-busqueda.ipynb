# %% [markdown]
# # 🐍 Clase 04: Algoritmos de Búsqueda: Lineal vs Binaria O(log n)
# ### **Curso 2: Algoritmos Avanzados y Estructuras de Datos**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-04-algoritmos-busqueda.ipynb)
#
# > **Metáfora Central:** *«Búsqueda Binaria como Buscar una Palabra en el Diccionario Dividiendo a la Mitad»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# Buscar elementos en grandes volúmenes de datos requiere algoritmos más inteligentes que la simple inspección secuencial.
#
# > **Metáfora Didáctica:** Para encontrar la página 500 de un libro de 1000 páginas, lo abres a la mitad exacta y descartas 500 páginas de golpe.
#
# Búsqueda Lineal O(n): Inspecciona uno a uno. Funciona en listas desordenadas.
#
# Búsqueda Binaria O(log n): Requiere que la lista esté estrictamente ordenada. En 1 millón de elementos tarda máximo 20 pasos.
#
# **⚡ Regla de Oro:** La búsqueda binaria solo es válida sobre arreglos previamente ordenados.

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Implementación de Búsqueda Binaria pura y módulo bisect:

# %%
# CLASE 04 - Demostración
import bisect

def busqueda_binaria(arr: list[int], target: int) -> int:
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

datos = [10, 20, 30, 40, 50, 60, 70, 80]
idx = busqueda_binaria(datos, 60)
print("Índice de 60:", idx)  # 5
print("Índice con bisect_left:", bisect.bisect_left(datos, 60))

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Escribir while left < right en lugar de left <= right omite evaluar el último elemento restante.
#
# 💡 **Consejo Profesional:** Usa bisect.insort para insertar elementos manteniendo siempre la lista ordenada.

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Modifica la búsqueda binaria para encontrar la primera y última posición de un elemento repetido.
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
