# %% [markdown]
# # 🐍 Clase 08: Recursividad y Programación Dinámica con Memoización
# ### **Curso 2: Algoritmos Avanzados y Estructuras de Datos**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-08-recursividad-y-programacion-dinamica.ipynb)
#
# > **Metáfora Central:** *«Programación Dinámica como Recordar el Pasado para no Resolverlo Dos Veces»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# La programación dinámica es una técnica de optimización que almacena los resultados de subproblemas ya resueltos.
#
# > **Metáfora Didáctica:** Si te pregunto cuánto es 1+1+1+1, cuentas 4. Si añado otro +1, sabes que es 5 porque recordaste el 4 anterior.
#
# Recursión simple (Naive): Resuelve los mismos subproblemas miles de veces (explosión exponencial O(2^n)).
#
# Memoización (Top-Down): Guarda en una tabla hash el resultado de cada llamada de función.
#
# **⚡ Regla de Oro:** En Python, decora tus funciones recursivas puras con @functools.lru_cache(maxsize=None).

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Optimización extrema de Fibonacci con @lru_cache:

# %%
# CLASE 08 - Demostración
from functools import lru_cache
import time

@lru_cache(maxsize=None)
def fibonacci(n: int) -> int:
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

t0 = time.perf_counter()
res = fibonacci(50)
t1 = time.perf_counter()

print(f"Fibonacci(50) = {res}")
print(f"Calculado en: {(t1 - t0)*1000:.4f} ms (Tiempo O(n))")

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Recursiones muy profundas superan el límite de la pila de llamadas (por defecto 1000).
#
# 💡 **Consejo Profesional:** Siempre que puedas, traduce algoritmos recursivos a tablas iterativas (Tabulación).

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Resuelve el problema del cambio de monedas (mínimo número de monedas para formar un monto) usando DP.
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
