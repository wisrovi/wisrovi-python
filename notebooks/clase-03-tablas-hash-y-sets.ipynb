# %% [markdown]
# # 🐍 Clase 03: Tablas Hash y Conjuntos (Sets) para Búsqueda O(1)
# ### **Curso 2: Algoritmos Avanzados y Estructuras de Datos**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-03-tablas-hash-y-sets.ipynb)
#
# > **Metáfora Central:** *«Tablas Hash como un Fichero con Índice Alfabético Instantáneo»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# Las tablas hash convierten una clave arbitraria en un índice numérico mediante una función matemática de hashing.
#
# > **Metáfora Didáctica:** Es como un conserje de hotel que sabe instantáneamente el casillero de cada huésped con solo mirar su apellido.
#
# Las colisiones ocurren cuando dos claves distintas generan el mismo hash; CPython usa open addressing con perturbación.
#
# Las operaciones de inserción, búsqueda y eliminación en sets y dicts tienen complejidad temporal promedio O(1).
#
# **⚡ Regla de Oro:** Cualquier objeto que uses como clave de diccionario o elemento de set debe implementar __hash__ e inmutabilidad.

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Problema clásico Two-Sum resuelto en O(n) con tabla hash:

# %%
# CLASE 03 - Demostración
def two_sum(nums: list[int], target: int) -> tuple[int, int]:
    vistos = {}  # mapa: valor -> indice
    for i, num in enumerate(nums):
        complemento = target - num
        if complemento in vistos:
            return (vistos[complemento], i)
        vistos[num] = i
    return (-1, -1)

indices = two_sum([2, 7, 11, 15], 9)
print("Índices que suman 9:", indices)  # (0, 1)

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Intentar usar una lista mutable como clave de diccionario o elemento de set genera TypeError: unhashable type.
#
# 💡 **Consejo Profesional:** Para agrupar elementos por propiedades, usa collections.defaultdict(list).

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Implementa una función que encuentre el primer carácter no repetido en una cadena en tiempo O(n).
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
