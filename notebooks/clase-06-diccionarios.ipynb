# %% [markdown]
# # 🐍 Clase 06: Diccionarios y Conjuntos (Sets)
# ### **Curso 1: Fundamentos Básicos de Python**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-06-diccionarios.ipynb)
#
# > **Metáfora Central:** *«Diccionarios como un Casillero con Llaves Únicas»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# Los diccionarios son colecciones asociativas basadas en pares clave-valor que permiten accesos ultra rápidos.
#
# > **Metáfora Didáctica:** Un diccionario es como un casillero: con tu llave (clave) abres instantáneamente el compartimento (valor).
#
# Las claves deben ser objetos inmutables y hashables (strings, números, tuplas).
#
# Los conjuntos (sets) son colecciones no ordenadas de elementos únicos.
#
# **⚡ Regla de Oro:** Usa siempre diccionario.get('clave', default) para evitar excepciones KeyError.

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Modelado de usuario y consulta segura:

# %%
# CLASE 06 - Demostración
usuario = {
    "id": 101,
    "nombre": "Carlos Ruiz",
    "roles": {"admin", "editor"},
    "activo": True
}

email = usuario.get("email", "sin_correo@empresa.com")
print(f"Usuario: {usuario['nombre']} | Email: {email}")

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Hacer data['no_existe'] lanza KeyError en lugar de devolver None.
#
# 💡 **Consejo Profesional:** Utiliza collections.defaultdict para inicializar contadores automáticos.

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Crea una función que reciba un texto y cuente la frecuencia de cada palabra con un diccionario.
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
