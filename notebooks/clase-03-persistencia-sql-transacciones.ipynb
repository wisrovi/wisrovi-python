# %% [markdown]
# # 🐍 Clase 03: Persistencia de Datos: Modelado SQL y Transacciones ACID
# ### **Curso 4: Taller Práctico & Proyecto Final Integrador**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-03-persistencia-sql-transacciones.ipynb)
#
# > **Metáfora Central:** *«La Base de Datos como una Bóveda Acorazada para la Información»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# La persistencia de datos garantiza que la información de los usuarios permanezca intacta tras apagar o reiniciar el servidor.
#
# > **Metáfora Didáctica:** Una transacción ACID es como una transferencia bancaria: o se descuenta de una cuenta y se acredita en la otra, o se cancela todo.
#
# Inyección SQL: La vulnerabilidad #1 de bases de datos. Ocurre al concatenar strings en consultas.
#
# Consultas parametrizadas: Separan el código SQL de los datos proporcionados por el usuario.
#
# **⚡ Regla de Oro:** NUNCA concatenes variables en consultas SQL; usa siempre placeholders (?, %s o :val).

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Capa de persistencia relacional con consultas parametrizadas:

# %%
# CLASE 03 - Demostración
import sqlite3

class RepositorioUsuarios:
    def __init__(self, db_path: str = "app.db"):
        self.db_path = db_path
        self._crear_tabla()

    def _crear_tabla(self):
        with sqlite3.connect(self.db_path) as conn:
            conn.execute("""
                CREATE TABLE IF NOT EXISTS usuarios (
                    id INTEGER PRIMARY KEY AUTOINCREMENT,
                    nombre TEXT NOT NULL,
                    email TEXT UNIQUE NOT NULL
                )
            """)

    def insertar(self, nombre: str, email: str) -> int:
        with sqlite3.connect(self.db_path) as conn:
            cursor = conn.cursor()
            cursor.execute("INSERT INTO usuarios (nombre, email) VALUES (?, ?)", (nombre, email))
            return cursor.lastrowid

repo = RepositorioUsuarios(":memory:")
uid = repo.insertar("Wisrovi Developer", "wisrovi@dev.com")
print(f"Usuario insertado con ID: {uid}")

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Formatear strings con f-strings en SQL permite a atacantes ejecutar comandos destructivos (ej. ' OR 1=1; DROP TABLE...).
#
# 💡 **Consejo Profesional:** Usa SQLAlchemy o SQLModel para proyectos de gran escala con mapeo objeto-relacional.

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Crea una tabla 'pedidos' vinculada por clave foránea (FOREIGN KEY) a la tabla de usuarios.
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
