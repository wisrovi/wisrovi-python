# %% [markdown]
# # 🐍 Clase 07: Containerización Profesional con Docker y Compose
# ### **Curso 4: Taller Práctico & Proyecto Final Integrador**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/notebooks/clase-07-docker-y-compose.ipynb)
#
# > **Metáfora Central:** *«Docker como Contenedores Estándar de Carga Marítima para Software»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica
#
# Docker elimina el famoso problema de 'en mi máquina sí funciona' empaquetando el código con todas sus dependencias.
#
# > **Metáfora Didáctica:** Un contenedor Docker es como un contenedor de barco: no importa si va en tren o camión, su contenido viaja aislado y seguro.
#
# Dockerfile: La receta paso a paso para construir la imagen del contenedor.
#
# Docker Compose: La herramienta para definir y correr aplicaciones multi-contenedor con un solo comando.
#
# **⚡ Regla de Oro:** Usa imágenes base ligeras (ej. python:3.11-slim) para reducir el tamaño y vulnerabilidades.

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Configuración estándar de Dockerfile y Docker Compose:

# %%
# CLASE 07 - Demostración
DOCKERFILE_EXAMPLE = """FROM python:3.11-slim
WORKDIR /app
COPY requirements.txt .
RUN pip install --no-cache-dir -r requirements.txt
COPY . .
EXPOSE 8000
CMD ["uvicorn", "main:app", "--host", "0.0.0.0", "--port", "8000"]"""

print("Dockerfile de producción configurado:")
print(DOCKERFILE_EXAMPLE)

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** Usar imágenes completas basadas en Ubuntu instala compiladores innecesarios generando imágenes de más de 2 GB.
#
# 💡 **Consejo Profesional:** Crea un archivo .dockerignore para evitar copiar venv, git y cachés dentro de la imagen.

# %% [markdown]
# ## 4. 🏋️ Desafío de Práctica
#
# > **Reto:** Crea un archivo docker-compose.yml que levante un servicio web y un servicio de Redis.
#
# Escribe y ejecuta tu solución en la celda siguiente:

# %%
# Tu solución aquí:
