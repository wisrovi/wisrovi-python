# %% [markdown]
# # 🐍 Clase 02: Variables, Tipos de Datos y Operadores
# ### **Curso 1: Fundamentos Básicos de Python (CLASE 02)**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wisrovi/wisrovi-python/blob/main/01-fundamentos-python/clase-02-variables-y-tipos/clase-02-variables-y-tipos.ipynb)
#
# > **Metáfora Central:** *«Variables como Cajas Etiquetadas en Memoria»*
# > **Instructor:** **William Rodríguez (Wisrovi)** (AI Solutions Architect & Principal Software Engineer)
# > **Licencia:** MIT | **Python:** 3.10+
#
# ---

# %% [markdown]
# ## 1. 💡 Fundamentación Teórica y Modelo Mental
#
# En Python, las variables no almacenan el dato directamente, sino una referencia a un objeto en el heap de memoria.
#
# > **Metáfora Didáctica:** Una variable es una etiqueta adhesiva pegada a una caja; varias etiquetas pueden apuntar a la misma caja.
#
# Python es fuertemente tipado: no convierte tipos automáticamente sin orden explícita.
#
# Los tipos primitivos (int, float, str, bool) son inmutables en memoria.
#
# **⚡ Regla de Oro en Python:** Convierte tipos explícitamente usando int() o float() antes de operar con entradas de usuario.

# %% [markdown]
# ## 2. 💻 Implementación de Código Ejecutable
#
# Operaciones matemáticas y tipado seguro:

# %%
# CLASE 02 - Código de Demostración
edad: int = 28
precio: float = 19.99
nombre: str = "Wisrovi"
es_activo: bool = True

total = precio * 2
print(f"Usuario: {nombre} | Total a pagar: ${total:.2f}")

# %% [markdown]
# ## 3. 🛡️ Buenas Prácticas y Trampas Frecuentes
#
# ⚠️ **Gotcha:** input() siempre retorna un string; sumarlo directamente concatena texto.
#
# 💡 **Consejo Profesional:** Siempre valida con bloques try/except al convertir entradas de usuario a números.

# %% [markdown]
# ## 4. 🏋️ Desafío Práctico de la Clase
#
# > **Reto:** Crea una calculadora de propinas que solicite el total de la cuenta y el porcentaje deseado.
#
# ¡Escribe y prueba tu solución en la siguiente celda interactiva!

# %%
# Escribe tu solución aquí:
